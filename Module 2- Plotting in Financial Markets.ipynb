# %% [markdown]
# # Module 2- Plotting in Financial Markets

# %% [markdown]
#    ### Welcome to the Answer notebook for Module 2 !
# Make sure that you've submitted the module 1 notebook and unlocked Module 2 yourself before you start coding here

# %% [markdown]
# #--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------#

# %% [markdown]
# ### Query 2.1
# Load the week2.csv file into a dataframe. What is the type of the Date column? Make sure it is of type datetime64. Convert the Date column to the index of the dataframe.
# Plot the closing price of each of the days for the entire time frame to get an idea of what the general outlook of the stock is.
#
# >Look out for drastic changes in this stock, you have the exact date when these took place, try to fetch the news for this day of this stock
#
# >This would be helpful if we are to train our model to take NLP inputs.

# %%
import numpy as np 
import pandas as pd
train2 = pd.read_csv('week2.csv')
train2.head()
# Out:
#      Symbol Series        Date  Prev Close  Open Price  High Price  Low Price  \
# 0  JUBLFOOD     EQ  2017-05-15      986.35      991.85     1031.00     983.55
# 1  JUBLFOOD     EQ  2017-05-16     1025.45     1028.50     1054.85    1028.50
# 2  JUBLFOOD     EQ  2017-05-17     1050.65     1044.00     1058.75    1024.20
# 3  JUBLFOOD     EQ  2017-05-18     1049.05     1039.70     1049.15    1012.20
# 4  JUBLFOOD     EQ  2017-05-19     1019.35     1022.00     1042.20    1011.00
#
#    Last Price  Close Price  Average Price  Total Traded Quantity  \
# 0     1029.60      1025.45        1009.72                 576466
# 1     1052.00      1050.65        1042.26                 487510
# 2     1047.00      1049.05        1039.93                 393751
# 3     1014.10      1019.35        1033.80                 381432
# 4     1012.55      1018.10        1025.24                 287852
#
#        Turnover  No. of Trades  Deliverable Qty  % Dly Qt to Traded Qty  \
# 0  5.820685e+08          19888           115368                   20.01
# 1  5.081107e+08          15487            84859                   17.41
# 2  4.094726e+08          15205            61936                   15.73
# 3  3.943245e+08          10345            40599                   10.64
# 4  2.951171e+08           9834            60049                   20.86
#
#    Month  Year      vwap_num  Day_Perc_Change                Trend
# 0      5  2017  5.911371e+08         0.000000  Slight or No change
# 1      5  2017  5.122024e+08         2.457458             Positive
# 2      5  2017  4.130645e+08        -0.152287  Slight or No change
# 3      5  2017  3.888127e+08        -2.831133             Negative
# 4      5  2017  2.930621e+08        -0.122627  Slight or No change

# %%
train2.dtypes
# Out:
# Symbol                     object
# Series                     object
# Date                       object
# Prev Close                float64
# Open Price                float64
# High Price                float64
# Low Price                 float64
# Last Price                float64
# Close Price               float64
# Average Price             float64
# Total Traded Quantity       int64
# Turnover                  float64
# No. of Trades               int64
# Deliverable Qty             int64
# % Dly Qt to Traded Qty    float64
# Month                       int64
# Year                        int64
# vwap_num                  float64
# Day_Perc_Change           float64
# Trend                      object
# dtype: object

# %%
train2['Date'].astype('datetime64')
# Out:
# 0     2017-05-15
# 1     2017-05-16
# 2     2017-05-17
# 3     2017-05-18
# 4     2017-05-19
# 5     2017-05-22
# 6     2017-05-23
# 7     2017-05-24
# 8     2017-05-25
# 9     2017-05-26
# 10    2017-05-29
# 11    2017-05-30
# 12    2017-05-31
# 13    2017-06-01
# 14    2017-06-02
# 15    2017-06-05
# 16    2017-06-06
# 17    2017-06-07
# 18    2017-06-08
# 19    2017-06-09
# 20    2017-06-12
# 21    2017-06-13
# 22    2017-06-14
# 23    2017-06-15
# 24    2017-06-16
# 25    2017-06-19
# 26    2017-06-20
# 27    2017-06-21
# 28    2017-06-22
# 29    2017-06-23
#          ...
# 464   2019-03-27
# 465   2019-03-28
# 466   2019-03-29
# 467   2019-04-01
# 468   2019-04-02
# 469   2019-04-03
# 470   2019-04-04
# 471   2019-04-05
# 472   2019-04-08
# 473   2019-04-09
# 474   2019-04-10
# 475   2019-04-11
# 476   2019-04-12
# 477   2019-04-15
# 478   2019-04-16
# 479   2019-04-18
# 480   2019-04-22
# 481   2019-04-23
# 482   2019-04-24
# 483   2019-04-25
# 484   2019-04-26
# 485   2019-04-30
# 486   2019-05-02
# 487   2019-05-03
# 488   2019-05-06
# 489   2019-05-07
# 490   2019-05-08
# 491   2019-05-09
# 492   2019-05-10
# 493   2019-05-13
# Name: Date, Length: 494, dtype: datetime64[ns]

# %%
train2.set_index('Date')
# Out:
#               Symbol Series  Prev Close  Open Price  High Price  Low Price  \
# Date
# 2017-05-15  JUBLFOOD     EQ      986.35      991.85     1031.00     983.55
# 2017-05-16  JUBLFOOD     EQ     1025.45     1028.50     1054.85    1028.50
# 2017-05-17  JUBLFOOD     EQ     1050.65     1044.00     1058.75    1024.20
# 2017-05-18  JUBLFOOD     EQ     1049.05     1039.70     1049.15    1012.20
# 2017-05-19  JUBLFOOD     EQ     1019.35     1022.00     1042.20    1011.00
# 2017-05-22  JUBLFOOD     EQ     1018.10     1018.10     1038.00    1015.00
# 2017-05-23  JUBLFOOD     EQ     1030.30     1030.00     1030.00     990.00
# 2017-05-24  JUBLFOOD     EQ      993.15      995.00     1005.90     966.00
# 2017-05-25  JUBLFOOD     EQ      976.45      974.45     1024.00     965.25
# 2017-05-26  JUBLFOOD     EQ     1014.95     1024.00     1035.00     982.50
# 2017-05-29  JUBLFOOD     EQ      992.70      997.80      998.40     925.00
# 2017-05-30  JUBLFOOD     EQ      940.35      880.10      921.00     817.20
# 2017-05-31  JUBLFOOD     EQ      909.15      911.95      925.00     888.00
# 2017-06-01  JUBLFOOD     EQ      914.90      920.00      920.00     898.10
# 2017-06-02  JUBLFOOD     EQ      912.25      914.25      934.80     908.30
# 2017-06-05  JUBLFOOD     EQ      930.85      931.00      949.00     926.10
# 2017-06-06  JUBLFOOD     EQ      936.05      936.05      965.80     935.20
# 2017-06-07  JUBLFOOD     EQ      952.55      957.20      961.35     945.00
# 2017-06-08  JUBLFOOD     EQ      955.20      952.00      971.90     952.00
# 2017-06-09  JUBLFOOD     EQ      963.80      964.00      975.00     952.45
# 2017-06-12  JUBLFOOD     EQ      969.10      960.00      966.85     950.10
# 2017-06-13  JUBLFOOD     EQ      959.55      961.15      973.00     953.00
# 2017-06-14  JUBLFOOD     EQ      970.05      962.00      968.00     952.00
# 2017-06-15  JUBLFOOD     EQ      962.60      959.95      964.90     953.00
# 2017-06-16  JUBLFOOD     EQ      959.25      963.00      968.75     925.40
# 2017-06-19  JUBLFOOD     EQ      938.20      940.10      944.95     918.60
# 2017-06-20  JUBLFOOD     EQ      924.65      923.50      930.45     920.00
# 2019-05-09                    9.97      5  2019  8.196651e+08
# 2019-05-10                   12.35      5  2019  1.128450e+09
# 2019-05-13                   17.29      5  2019  9.275487e+08
#
#             Day_Perc_Change                Trend
# Date
# 2017-05-15         0.000000  Slight or No change
# 2017-05-16         2.457458             Positive
# 2017-05-17        -0.152287  Slight or No change
# 2017-05-18        -2.831133             Negative
# 2017-05-19        -0.122627  Slight or No change
# 2017-05-22         1.198311             Positive
# 2017-05-23        -3.605746     Among top losers
# 2017-05-24        -1.681518             Negative
# 2017-05-25         3.942854    Among top gainers
# 2017-05-26        -2.192226             Negative
# 2017-05-29        -5.273497     Among top losers
# 2017-05-30        -3.317914     Among top losers
# 2017-05-31         0.632459      Slight positive
# 2017-06-01        -0.289649  Slight or No change
# 2017-06-02         2.038915             Positive
# 2017-06-05         0.558629      Slight positive
# 2017-06-06         1.762726             Positive
# 2017-06-07         0.278201  Slight or No change
# 2017-06-08         0.900335      Slight positive
# 2017-06-09         0.549907      Slight positive
# 2017-06-12        -0.985450      Slight negative
# 2017-06-13         1.094263             Positive
# 2017-06-14        -0.768002      Slight negative
# 2017-06-15        -0.348016  Slight or No change
# 2017-06-16        -2.194423             Negative
# 2017-06-19        -1.444255             Negative
# 2017-06-20        -0.070297  Slight or No change
# 2017-06-21         0.238095  Slight or No change
# 2017-06-22        -1.398186             Negative
# 2017-06-23         1.062141             Positive
# ...                     ...                  ...
# 2019-03-27        -1.363698             Negative
# 2019-03-28         0.884833      Slight positive
# 2019-03-29        -1.055228             Negative
# 2019-04-01         1.128809             Positive
# 2019-04-02        -1.307950             Negative
# 2019-04-03        -1.252429             Negative
# 2019-04-04         0.681587      Slight positive
# 2019-04-05        -1.064312             Negative
# 2019-04-08         0.712472      Slight positive
# 2019-04-09         0.129579  Slight or No change
# 2019-04-10        -1.392046             Negative
# 2019-04-11        -2.436775             Negative
# 2019-04-12        -1.003417             Negative
# 2019-04-15         0.653691      Slight positive
# 2019-04-16         0.784442      Slight positive
# 2019-04-18        -2.606524             Negative
# 2019-04-22        -1.048210             Negative
# 2019-04-23        -1.123173             Negative
# 2019-04-24         0.068384  Slight or No change
# 2019-04-25         0.827639      Slight positive
# 2019-04-26         1.122072             Positive
# 2019-04-30        -1.064939             Negative
# 2019-05-02         1.309748             Positive
# 2019-05-03        -1.452560             Negative
# 2019-05-06        -1.997964             Negative
# 2019-05-07        -1.354002             Negative
# 2019-05-08        -1.544161             Negative
# 2019-05-09         0.502990      Slight positive
# 2019-05-10        -0.338903  Slight or No change
# 2019-05-13        -1.731910             Negative
#
# [494 rows x 19 columns]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
# plt.figure(figsize=(20,15))
train2.plot(x='Date',y='Close Price')

# %%
# plt.figure(figsize=(20,15))
train2.plot(y='Close Price')

# %%
# train2[train2['Day_Perc_Change'].min()]
train2.loc[train2['Day_Perc_Change'] == train2['Day_Perc_Change'].min()]
# Out:
#        Symbol Series        Date  Prev Close  Open Price  High Price  \
# 276  JUBLFOOD     EQ  2018-06-21      2723.0      1368.0     1385.25
#
#      Low Price  Last Price  Close Price  Average Price  Total Traded Quantity  \
# 276     1350.7      1361.8      1356.65        1360.09                 710681
#
#          Turnover  No. of Trades  Deliverable Qty  % Dly Qt to Traded Qty  \
# 276  9.665911e+08          29957            94301                   13.27
#
#      Month  Year      vwap_num  Day_Perc_Change      Trend
# 276      6  2018  9.641454e+08       -50.178112  Bear drop

# %% [markdown]
# ## Query 2.2
# A stem plot is a discrete series plot, ideal for plotting daywise data. It can be plotted using the plt.stem() function.
#
# Display a stem plot of the daily change in of the stock price in percentage. This column was calculated in module 1 and should be already available in week2.csv. Observe whenever there's a large change.

# %%
plt.figure(figsize=(40,15))
plt.stem(train2['Date'],train2['Day_Perc_Change'],'g',linewidth=10)
plt.show()
# Out:
# /opt/anaconda/lib/python3.6/site-packages/matplotlib/cbook/deprecation.py:107: MatplotlibDeprecationWarning: stem() got an unexpected keyword argument 'linewidth'. This will raise a TypeError in future versions.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %% [markdown]
# ## Query 2.3
# Plot the daily volumes as well and compare the percentage stem plot to it. Document your analysis of the relationship between volume and daily percentage change.

# %%
plt.figure(figsize=(40,15))

train2['No. of Trades'].plot(kind='line',x=train2['Date'],color='r')
plt.stem(train2['Date'],train2['Day_Perc_Change'],linefmt=None)
# plt.autoscale(enable=True, axis='both', tight=None)
plt.show()

# %% [markdown]
# ## Query 2.4
# We had created a Trend column in module 1. We want to see how often each Trend type occurs. This can be seen as a pie chart, with each sector representing the percentage of days each trend occurs. Plot a pie chart for all the 'Trend' to know about relative frequency of each trend. You can use the groupby function with the trend column to group all days with the same trend into a single group before plotting the pie chart. From the grouped data, create a BAR plot of average & median values of the 'Total Traded Quantity' by Trend type.

# %%
plt.figure(figsize=(10,10))
train2pie = train2.groupby('Trend').count()
train2pie['Symbol'].plot(kind='pie')
plt.show()

# %%
plt.figure(figsize=(12,7))
train2avg = train2.groupby('Trend').mean()
train2avg['Total Traded Quantity'].plot(kind='bar',color='g')
plt.show()

# %%
plt.figure(figsize=(12,7))
train2median = train2.groupby('Trend').median()
train2median['Total Traded Quantity'].plot(kind='bar',color='r')
plt.show()

# %% [markdown]
# ## Query 2.5
# Plot the daily return (percentage) distribution as a histogram.
# Histogram analysis is one of the most fundamental methods of exploratory data analysis. In this case, it'd return a frequency plot of various values of percentage changes .

# %%
plt.figure(figsize=(12,7))
train2['Day_Perc_Change'].plot(kind='hist')
plt.show()

# %% [markdown]
# ## Query 2.6
# We next want to analyse how the behaviour of different stocks are correlated. The correlation is performed on the percentage change of the stock price instead of the stock price.
#
# Load any 5 stocks of your choice into 5 dataframes. Retain only rows for which ‘Series’ column has value ‘EQ’. Create a single dataframe which contains the ‘Closing Price’ of each stock. This dataframe should hence have five columns. Rename each column to the name of the stock that is contained in the column. Create a new dataframe which is a percentage change of the values in the previous dataframe. Drop Nan’s from this dataframe.
# Using seaborn, analyse the correlation between the percentage changes in the five stocks. This is extremely useful for a fund manager to design a diversified portfolio. To know more, check out these resources on correlation and diversification.

# %%
adani = pd.read_csv('ADANIPOWER.csv')
castrol = pd.read_csv('CASTROLIND.csv')
gmr = pd.read_csv('GMRINFRA.csv')
godrej = pd.read_csv('GODREJIND.csv')
mindtree = pd.read_csv('MINDTREE.csv')

adani = adani[adani['Series']=='EQ']
gmr = gmr[gmr['Series']=='EQ']
godrej = godrej[godrej['Series']=='EQ']
castrol = castrol[castrol['Series']=='EQ']
mindtree = mindtree[mindtree['Series']=='EQ']

# %%
adani = adani['Close Price']
castrol = castrol['Close Price']
gmr = gmr['Close Price']
godrej = godrej['Close Price']
mindtree = mindtree['Close Price']
jublfood = train2['Close Price']

# %%
newdf = pd.concat([adani.rename('adani'),castrol.rename('castrol'),
                   gmr.rename('gmr'),godrej.rename('godrej'),mindtree.rename('mindtree'),jublfood.rename('jublfood')],axis=1)
newdf.head()
# Out:
#    adani  castrol    gmr  godrej  mindtree  jublfood
# 0  30.25   449.85  17.55  578.55    509.45   1025.45
# 1  32.85   443.00  17.40  584.80    511.30   1050.65
# 2  33.10   439.55  17.30  588.60    506.35   1049.05
# 3  31.90   433.95  16.75  574.60    492.90   1019.35
# 4  32.40   437.10  16.95  578.00    497.50   1018.10

# %%
newdf_pct = newdf.pct_change()*100
newdf_pct.drop(newdf_pct.index[0],inplace=True)
newdf_pct.head()
# Out:
#       adani   castrol       gmr    godrej  mindtree  jublfood
# 1  8.595041 -1.522730 -0.854701  1.080287  0.363137  2.457458
# 2  0.761035 -0.778781 -0.574713  0.649795 -0.968120 -0.152287
# 3 -3.625378 -1.274030 -3.179191 -2.378525 -2.656265 -2.831133
# 4  1.567398  0.725890  1.194030  0.591716  0.933252 -0.122627
# 5 -2.932099 -2.779684 -0.884956 -2.084775  0.974874  1.198311

# %%
sns.pairplot(newdf_pct)

# %% [markdown]
# ## Query 2.7
# Volatility is the change in variance in the returns of a stock over a specific period of time.Do give the following documentation on volatility a read.
# You have already calculated the percentage changes in several stock prices. Calculate the 7 day rolling average of the percentage change of any of the stock prices, then compute the standard deviation (which is the square root of the variance) and plot the values.
# Note: pandas provides a rolling() function for dataframes and a std() function also which you can use.

# %%
newdf_pct['adani_ra'] = newdf_pct['adani'].rolling(window=7,center=False).std()
newdf_pct['jublfood_ra'] = newdf_pct['jublfood'].rolling(window=7,center=False).std()
newdf_pct.head(20)
# Out:
#        adani   castrol        gmr    godrej  mindtree  jublfood  adani_ra  \
# 1   8.595041 -1.522730  -0.854701  1.080287  0.363137  2.457458       NaN
# 2   0.761035 -0.778781  -0.574713  0.649795 -0.968120 -0.152287       NaN
# 3  -3.625378 -1.274030  -3.179191 -2.378525 -2.656265 -2.831133       NaN
# 4   1.567398  0.725890   1.194030  0.591716  0.933252 -0.122627       NaN
# 5  -2.932099 -2.779684  -0.884956 -2.084775  0.974874  1.198311       NaN
# 6  -5.087440 -3.070950  -5.357143 -0.821627 -0.238877 -3.605746       NaN
# 7  -6.197655  1.675164  -8.490566  1.541065  1.755961 -1.681518  5.100736
# 8   2.321429 -1.038682   4.467354  2.447583  6.657515  3.942854  3.405744
# 9   0.872600  1.459766   4.934211  1.644117 -1.599559 -2.192226  3.420418
# 10 -7.612457 -0.856124  -7.210031 -1.390059 -0.868834 -5.273497  4.037927
# 11  2.434457  1.295275   1.351351  4.263135  1.291113 -3.317914  4.191656
# 12  1.279707  0.438077   0.333333 -0.925926  1.218831  0.632459  4.386004
# 13 -2.707581 -0.223977  -0.664452  1.778182 -1.204155 -0.289649  4.167620
# 14  0.927644 -1.134216  13.043478 -0.552576  0.465203  2.038915  3.627995
# 15 -1.470588 -1.362333  -1.183432  0.400392  3.250602  0.558629  3.440011
# 16  1.679104 -0.484614  -2.994012 -2.360218 -1.928424  1.762726  3.521678
# 17  0.366972  0.766983   2.777778  1.266983 -1.792574  0.278201  1.824492
# 18 -1.645338 -0.217470  -0.300300  0.312783  1.229279  0.900335  1.698079
# 19 -0.371747 -1.174476   2.409639  2.330352 -0.873965  0.549907  1.563699
# 20  3.731343 -1.274198   4.411765 -1.467404  0.194896 -0.985450  1.882670
#
#     jublfood_ra
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# 5           NaN
# 6           NaN
# 7      2.166070
# 8      2.561041
# 9      2.634587
# 10     3.079385
# 11     3.145620
# 12     3.069224
# 13     2.969959
# 14     3.187760
# 15     2.575175
# 16     2.730042
# 17     1.767816
# 18     0.817152
# 19     0.821236
# 20     1.001456

# %% [markdown]
# ## Query 2.8
# Calculate the volatility for the Nifty index and compare the 2. This leads us to a useful indicator known as 'Beta' ( We'll be covering this in length in Module 3)

# %%
nifty = pd.read_csv('Nifty50.csv')
nifty.head()
# Out:
#           Date     Open     High      Low    Close  Shares Traded  \
# 0  15-May-2017  9433.55  9449.25  9423.10  9445.40      145163953
# 1  16-May-2017  9461.00  9517.20  9456.35  9512.25      171709433
# 2  17-May-2017  9517.60  9532.60  9486.10  9525.75      211856040
# 3  18-May-2017  9453.20  9489.10  9418.10  9429.45      199340647
# 4  19-May-2017  9469.90  9505.75  9390.75  9427.90      259861396
#
#    Turnover (Rs. Cr)
# 0            7790.97
# 1            9209.89
# 2           10726.23
# 3           10782.46
# 4           11544.77

# %%
nifty_cp = nifty['Close']
nifty_cp = nifty_cp.pct_change()*100
nifty_cp.drop(nifty_cp.index[0],inplace=True)
nifty_cp.columns=['Nifty']
nifty_cp.head()
# Out:
# 1    0.707752
# 2    0.141922
# 3   -1.010944
# 4   -0.016438
# 5    0.109781
# Name: Close, dtype: float64

# %%
nifty_pct = nifty_cp.rolling(window=7,center=False).std()
train2['Beta'] = nifty_pct
train2.head(20)
# Out:
#       Symbol Series        Date  Prev Close  Open Price  High Price  \
# 0   JUBLFOOD     EQ  2017-05-15      986.35      991.85     1031.00
# 1   JUBLFOOD     EQ  2017-05-16     1025.45     1028.50     1054.85
# 2   JUBLFOOD     EQ  2017-05-17     1050.65     1044.00     1058.75
# 3   JUBLFOOD     EQ  2017-05-18     1049.05     1039.70     1049.15
# 4   JUBLFOOD     EQ  2017-05-19     1019.35     1022.00     1042.20
# 5   JUBLFOOD     EQ  2017-05-22     1018.10     1018.10     1038.00
# 6   JUBLFOOD     EQ  2017-05-23     1030.30     1030.00     1030.00
# 7   JUBLFOOD     EQ  2017-05-24      993.15      995.00     1005.90
# 8   JUBLFOOD     EQ  2017-05-25      976.45      974.45     1024.00
# 9   JUBLFOOD     EQ  2017-05-26     1014.95     1024.00     1035.00
# 10  JUBLFOOD     EQ  2017-05-29      992.70      997.80      998.40
# 11  JUBLFOOD     EQ  2017-05-30      940.35      880.10      921.00
# 12  JUBLFOOD     EQ  2017-05-31      909.15      911.95      925.00
# 13  JUBLFOOD     EQ  2017-06-01      914.90      920.00      920.00
# 14  JUBLFOOD     EQ  2017-06-02      912.25      914.25      934.80
# 15  JUBLFOOD     EQ  2017-06-05      930.85      931.00      949.00
# 16  JUBLFOOD     EQ  2017-06-06      936.05      936.05      965.80
# 17  JUBLFOOD     EQ  2017-06-07      952.55      957.20      961.35
# 18  JUBLFOOD     EQ  2017-06-08      955.20      952.00      971.90
# 19  JUBLFOOD     EQ  2017-06-09      963.80      964.00      975.00
#
#     Low Price  Last Price  Close Price  Average Price    ...         Turnover  \
# 0      983.55     1029.60      1025.45        1009.72    ...     5.820685e+08
# 1     1028.50     1052.00      1050.65        1042.26    ...     5.081107e+08
# 2     1024.20     1047.00      1049.05        1039.93    ...     4.094726e+08
# 3     1012.20     1014.10      1019.35        1033.80    ...     3.943245e+08
# 4     1011.00     1012.55      1018.10        1025.24    ...     2.951171e+08
# 5     1015.00     1022.85      1030.30        1026.60    ...     3.303982e+08
# 6      990.00      990.00       993.15        1009.44    ...     3.460831e+08
# 7      966.00      974.45       976.45         988.12    ...     4.427233e+08
# 8      965.25     1024.00      1014.95         998.09    ...     5.238030e+08
# 9      982.50      993.95       992.70        1013.20    ...     3.963857e+08
# 10     925.00      937.20       940.35         957.94    ...     9.338984e+08
# 11     817.20      910.20       909.15         876.28    ...     4.823600e+09
# 12     888.00      917.00       914.90         909.16    ...     1.086751e+09
# 13     898.10      912.50       912.25         909.03    ...     8.376544e+08
# 14     908.30      932.00       930.85         924.04    ...     5.733756e+08
# 15     926.10      932.10       936.05         940.24    ...     4.833136e+08
# 16     935.20      956.90       952.55         954.52    ...     1.141797e+09
# 17     945.00      956.45       955.20         952.61    ...     4.503459e+08
# 18     952.00      963.40       963.80         963.02    ...     4.818485e+08
# 19     952.45      973.00       969.10         962.46    ...     3.568708e+08
#
#     No. of Trades  Deliverable Qty  % Dly Qt to Traded Qty  Month  Year  \
# 0           19888           115368                   20.01      5  2017
# 1           15487            84859                   17.41      5  2017
# 2           15205            61936                   15.73      5  2017
# 3           10345            40599                   10.64      5  2017
# 4            9834            60049                   20.86      5  2017
# 5            9940            87006                   27.03      5  2017
# 6           12009            77703                   22.66      5  2017
# 7           12040            42627                    9.51      5  2017
# 8           23985           109155                   20.80      5  2017
# 9           17661            72571                   18.55      5  2017
# 10          24822           158323                   16.24      5  2017
# 11         135807           628329                   11.41      5  2017
# 12          35859           123904                   10.37      5  2017
# 13          22643           279276                   30.31      6  2017
# 14          19763           118969                   19.17      6  2017
# 15          13543           105374                   20.50      6  2017
# 16          34217           288991                   24.16      6  2017
# 17          12611            72293                   15.29      6  2017
# 18          11524            47326                    9.46      6  2017
# 19          12853            50945                   13.74      6  2017
#
#         vwap_num  Day_Perc_Change                Trend      Beta
# 0   5.911371e+08         0.000000  Slight or No change       NaN
# 1   5.122024e+08         2.457458             Positive       NaN
# 2   4.130645e+08        -0.152287  Slight or No change       NaN
# 3   3.888127e+08        -2.831133             Negative       NaN
# 4   2.930621e+08        -0.122627  Slight or No change       NaN
# 5   3.315887e+08         1.198311             Positive       NaN
# 6   3.404965e+08        -3.605746     Among top losers       NaN
# 7   4.374935e+08        -1.681518             Negative  0.550855
# 8   5.326488e+08         3.942854    Among top gainers  0.813855
# 9   3.883651e+08        -2.192226             Negative  0.883117
# 10  9.167482e+08        -5.273497     Among top losers  0.736272
# 11  5.004565e+09        -3.317914     Among top losers  0.726819
# 12  1.093613e+09         0.632459      Slight positive  0.735017
# 13  8.406229e+08        -0.289649  Slight or No change  0.661813
# 14  5.776027e+08         2.038915             Positive  0.602978
# 15  4.811606e+08         0.558629      Slight positive  0.325592
# 16  1.139436e+09         1.762726             Positive  0.252962
# 17  4.515708e+08         0.278201  Slight or No change  0.265875
# 18  4.822402e+08         0.900335      Slight positive  0.276247
# 19  3.593345e+08         0.549907      Slight positive  0.282219
#
# [20 rows x 21 columns]

# %%
plt.figure(figsize=(20,10))
nifty_pct.plot(kind='line',color='r')
newdf_pct['adani_ra'].plot(kind='line',color='b')
newdf_pct['jublfood_ra'].plot(kind='line',color='g')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-e11e08715ce5> in <module>()
# ----> 1 plt.figure(figsize=(20,10))
#       2 nifty_pct.plot(kind='line',color='r')
#       3 newdf_pct['adani_ra'].plot(kind='line',color='b')
#       4 newdf_pct['jublfood_ra'].plot(kind='line',color='g')
#       5 plt.show()
#
# NameError: name 'plt' is not defined

# %% [markdown]
# ## Query 2.9
# Plot the 21 day and 34 day Moving average with the average price and decide a Call !
# Call should be buy whenever the smaller moving average (21) crosses over longer moving average (34) AND the call should be sell whenever smaller moving average crosses under longer moving average.
# One of the most widely used technical indicators.

# %%
buysell = train2['Average Price']
train2['Sma'] = buysell.rolling(window=21,center=False).mean()
train2['Lma'] = buysell.rolling(window=34,center=False).mean()

# %%
plt.figure(figsize=(20,10))
buysell.plot(kind='line',color='r')
train2['Sma'].plot(kind='line',color='b')
train2['Lma'].plot(kind='line',color='g')
plt.show()

# %% [markdown]
# ## Query 2.10
#  Trade Calls - Using Bollinger Bands
# Plot the bollinger bands for this stock - the duration of 14 days and 2 standard deviations away from the average
# The bollinger bands comprise the following data points-
# The 14 day rolling mean of the closing price (we call it the average)
# Upper band which is the rolling mean + 2 standard deviations away from the average.
# Lower band which is the rolling mean - 2 standard deviations away from the average.
# Average Daily stock price.
# Bollinger bands are extremely reliable , with a 95% accuracy at 2 standard deviations , and especially useful in sideways moving market.
# Observe the bands yourself , and analyse the accuracy of all the trade signals provided by the bollinger bands.
# Save to a new csv file.

# %%
train2['bollinger'] = buysell.rolling(window=14,center=False).mean()
std = buysell.rolling(window=14,center=False).std()
train2['upper'] = train2['bollinger'] + (std*2)
train2['lower'] = train2['bollinger'] - (std*2)

plt.figure(figsize=(20,10))
buysell.plot(kind='line',color='black')
train2['upper'].plot(kind='line',color='g')
train2['lower'].plot(kind='line',color='r')
train2['bollinger'].plot(kind='line',color='b')
plt.show()

# %%
train2.to_csv('week3.csv',index=False)
