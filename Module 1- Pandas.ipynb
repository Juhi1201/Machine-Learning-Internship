# %% [markdown]
# # Module 1

# %% [markdown]
#    ### Welcome to the Answer notebook for Module 1 !
# These notebooks have been provided to code and solve all the queries asked in the modules.
#
# This environment has all the necessary libraries pre-installed, and all the Stock, Commodities and Index data files available at the following location -

# %% [markdown]
# #### The problem statements and their corresponding answers are expected to be in the following format -

# %% [markdown]
# #--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------#

# %% [markdown]
# ### Query 1.1
# Import the csv file of the stock of your choosing using 'pd.read_csv()' function into a dataframe.
# Shares of a company can be offered in more than one category. The category of a stock is indicated in the ‘Series’ column. If the csv file has data on more than one category, the ‘Date’ column will have repeating values. To avoid repetitions in the date, remove all the rows where 'Series' column is NOT 'EQ'.
# Analyze and understand each column properly.
# You'd find the head(), tail() and describe() functions to be immensely useful for exploration. You're free to carry out any other exploration of your own.

# %%
#The solution code should start right after the query statement, for example -
import numpy as np 
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
#And solve the query
path='jublfood.csv'
train = pd.read_csv(path)
train
# Out:
#        Symbol Series         Date  Prev Close  Open Price  High Price  \
# 0    JUBLFOOD     EQ  15-May-2017      986.35      991.85     1031.00
# 1    JUBLFOOD     EQ  16-May-2017     1025.45     1028.50     1054.85
# 2    JUBLFOOD     EQ  17-May-2017     1050.65     1044.00     1058.75
# 3    JUBLFOOD     EQ  18-May-2017     1049.05     1039.70     1049.15
# 4    JUBLFOOD     EQ  19-May-2017     1019.35     1022.00     1042.20
# 5    JUBLFOOD     EQ  22-May-2017     1018.10     1018.10     1038.00
# 6    JUBLFOOD     EQ  23-May-2017     1030.30     1030.00     1030.00
# 7    JUBLFOOD     EQ  24-May-2017      993.15      995.00     1005.90
# 8    JUBLFOOD     EQ  25-May-2017      976.45      974.45     1024.00
# 9    JUBLFOOD     EQ  26-May-2017     1014.95     1024.00     1035.00
# 10   JUBLFOOD     EQ  29-May-2017      992.70      997.80      998.40
# 11   JUBLFOOD     EQ  30-May-2017      940.35      880.10      921.00
# 12   JUBLFOOD     EQ  31-May-2017      909.15      911.95      925.00
# 13   JUBLFOOD     EQ  01-Jun-2017      914.90      920.00      920.00
# 14   JUBLFOOD     EQ  02-Jun-2017      912.25      914.25      934.80
# 15   JUBLFOOD     EQ  05-Jun-2017      930.85      931.00      949.00
# 16   JUBLFOOD     EQ  06-Jun-2017      936.05      936.05      965.80
# 17   JUBLFOOD     EQ  07-Jun-2017      952.55      957.20      961.35
# 18   JUBLFOOD     EQ  08-Jun-2017      955.20      952.00      971.90
# 19   JUBLFOOD     EQ  09-Jun-2017      963.80      964.00      975.00
# 20   JUBLFOOD     EQ  12-Jun-2017      969.10      960.00      966.85
# 21   JUBLFOOD     EQ  13-Jun-2017      959.55      961.15      973.00
# 22   JUBLFOOD     EQ  14-Jun-2017      970.05      962.00      968.00
# 23   JUBLFOOD     EQ  15-Jun-2017      962.60      959.95      964.90
# 24   JUBLFOOD     EQ  16-Jun-2017      959.25      963.00      968.75
# 25   JUBLFOOD     EQ  19-Jun-2017      938.20      940.10      944.95
# 26   JUBLFOOD     EQ  20-Jun-2017      924.65      923.50      930.45
# 27   JUBLFOOD     EQ  21-Jun-2017      924.00      923.00      938.10
#
#          Turnover  No. of Trades  Deliverable Qty  % Dly Qt to Traded Qty
# 0    5.820685e+08          19888           115368                   20.01
# 1    5.081107e+08          15487            84859                   17.41
# 2    4.094726e+08          15205            61936                   15.73
# 3    3.943245e+08          10345            40599                   10.64
# 4    2.951171e+08           9834            60049                   20.86
# 5    3.303982e+08           9940            87006                   27.03
# 6    3.460831e+08          12009            77703                   22.66
# 7    4.427233e+08          12040            42627                    9.51
# 8    5.238030e+08          23985           109155                   20.80
# 9    3.963857e+08          17661            72571                   18.55
# 10   9.338984e+08          24822           158323                   16.24
# 11   4.823600e+09         135807           628329                   11.41
# 12   1.086751e+09          35859           123904                   10.37
# 13   8.376544e+08          22643           279276                   30.31
# 14   5.733756e+08          19763           118969                   19.17
# 15   4.833136e+08          13543           105374                   20.50
# 16   1.141797e+09          34217           288991                   24.16
# 17   4.503459e+08          12611            72293                   15.29
# 18   4.818485e+08          11524            47326                    9.46
# 19   3.568708e+08          12853            50945                   13.74
# 20   2.551118e+08           7100            38470                   14.47
# 21   4.069902e+08           9885            51514                   12.22
# 22   3.115560e+08          11365            21369                    6.58
# 23   2.219836e+08           9126            32167                   13.88
# 24   4.695588e+08          13784            86728                   17.47
# 25   6.096039e+08          19540           236955                   36.07
# 26   2.699727e+08           6213            73743                   25.26
# 27   4.272873e+08          13193            72380                   15.72
# 28   3.337193e+08          11738            51771                   14.25
# 29   5.307692e+08          17602           147377                   25.56
# ..            ...            ...              ...                     ...
# 465  1.607758e+09          38661           206795                   18.71
# 466  2.108444e+09          45697           559838                   38.63
# 467  1.738212e+09          56218           253228                   21.06
# 468  2.064987e+09          37393           318896                   22.72
# 469  1.545236e+09          32877           273389                   25.75
# 470  1.307854e+09          36560           279220                   30.76
# 471  1.414576e+09          39507           274042                   27.70
# 472  1.344850e+09          38794           269564                   28.53
# 473  1.169276e+09          33112           178347                   21.74
# 474  1.229135e+09          36292           180677                   20.92
# 475  9.563370e+08          34994           234777                   34.78
# 476  1.975911e+09          53260           398065                   27.95
# 477  2.102066e+09          67576           546206                   35.38
# 478  1.527835e+09          37947           296757                   26.68
# 479  1.754656e+09          56349           441571                   34.75
# 480  1.795303e+09          50037           347632                   26.29
# 481  9.948214e+08          23145           189283                   25.36
# 482  1.277800e+09          29448           219331                   22.87
# 483  1.275013e+09          63309           329221                   34.03
# 484  1.545897e+09          35270           216555                   18.77
# 485  1.755541e+09          38949           365697                   27.97
# 486  1.186226e+09          31362           347703                   38.78
# 487  2.017689e+09          48699           496442                   33.15
# 488  1.390174e+09          26366           190940                   18.44
# 489  1.475337e+09          37430           237505                   20.95
# 490  1.702720e+09          35689           247667                   18.91
# 491  1.313462e+09          34996           123192                   11.85
# 492  8.182635e+08          22188            64429                    9.97
# 493  1.140898e+09          25374           110213                   12.35
# 494  9.379148e+08          28142           129094                   17.29
#
# [495 rows x 15 columns]

# %%
#Once the solution of the first query is written, it should immediately be followed by the next query
train = train[train.Series == 'EQ']
train.head()
# Out:
#      Symbol Series         Date  Prev Close  Open Price  High Price  \
# 0  JUBLFOOD     EQ  15-May-2017      986.35      991.85     1031.00
# 1  JUBLFOOD     EQ  16-May-2017     1025.45     1028.50     1054.85
# 2  JUBLFOOD     EQ  17-May-2017     1050.65     1044.00     1058.75
# 3  JUBLFOOD     EQ  18-May-2017     1049.05     1039.70     1049.15
# 4  JUBLFOOD     EQ  19-May-2017     1019.35     1022.00     1042.20
#
#    Low Price  Last Price  Close Price  Average Price  Total Traded Quantity  \
# 0     983.55     1029.60      1025.45        1009.72                 576466
# 1    1028.50     1052.00      1050.65        1042.26                 487510
# 2    1024.20     1047.00      1049.05        1039.93                 393751
# 3    1012.20     1014.10      1019.35        1033.80                 381432
# 4    1011.00     1012.55      1018.10        1025.24                 287852
#
#        Turnover  No. of Trades  Deliverable Qty  % Dly Qt to Traded Qty
# 0  5.820685e+08          19888           115368                   20.01
# 1  5.081107e+08          15487            84859                   17.41
# 2  4.094726e+08          15205            61936                   15.73
# 3  3.943245e+08          10345            40599                   10.64
# 4  2.951171e+08           9834            60049                   20.86

# %% [markdown]
# ### Query 1.2
# Calculate the maximum, minimum and mean price for the last 90 days. (price=Closing Price unless stated otherwise)

# %%
#And so on !
# train['Date'].value_counts(ascending=True
from datetime import timedelta
train['Date']=pd.to_datetime(train['Date'])
x=(train['Date'].max() - np.timedelta64(89,'D'))
query1_2 = train[(train['Date']>=x)]
print("Maximum Price: %f" %query1_2['Close Price'].max())
print("Minimum Price: %f" %query1_2['Close Price'].min())
print("Mean Price: %f" %(query1_2['Close Price'].sum()/90))
# Out:
# Maximum Price: 1466.600000
# Minimum Price: 1242.600000
# Mean Price: 869.351111

# %% [markdown]
# **This is the expected format of the answer notebook**
# ### Query 1.3

# %% [markdown]
# 1.3 Analyse the data types for each column of the dataframe. Pandas knows how to deal with dates in an intelligent manner. But to make use of Pandas functionality for dates, you need to ensure that the column is of type 'datetime64(ns)'. Change the date column from 'object' type to 'datetime64(ns)' for future convenience. See what happens if you subtract the minimum value of the date column from the maximum value.

# %%
#So remove the comments and start coding !
train['Date'].astype('datetime64')
# Out:
# 0     2017-05-15
# 1     2017-05-16
# 2     2017-05-17
# 3     2017-05-18
# 4     2017-05-19
# 5     2017-05-22
# 6     2017-05-23
# 7     2017-05-24
# 8     2017-05-25
# 9     2017-05-26
# 10    2017-05-29
# 11    2017-05-30
# 12    2017-05-31
# 13    2017-06-01
# 14    2017-06-02
# 15    2017-06-05
# 16    2017-06-06
# 17    2017-06-07
# 18    2017-06-08
# 19    2017-06-09
# 20    2017-06-12
# 21    2017-06-13
# 22    2017-06-14
# 23    2017-06-15
# 24    2017-06-16
# 25    2017-06-19
# 26    2017-06-20
# 27    2017-06-21
# 28    2017-06-22
# 29    2017-06-23
#          ...
# 465   2019-03-27
# 466   2019-03-28
# 467   2019-03-29
# 468   2019-04-01
# 469   2019-04-02
# 470   2019-04-03
# 471   2019-04-04
# 472   2019-04-05
# 473   2019-04-08
# 474   2019-04-09
# 475   2019-04-10
# 476   2019-04-11
# 477   2019-04-12
# 478   2019-04-15
# 479   2019-04-16
# 480   2019-04-18
# 481   2019-04-22
# 482   2019-04-23
# 483   2019-04-24
# 484   2019-04-25
# 485   2019-04-26
# 486   2019-04-30
# 487   2019-05-02
# 488   2019-05-03
# 489   2019-05-06
# 490   2019-05-07
# 491   2019-05-08
# 492   2019-05-09
# 493   2019-05-10
# 494   2019-05-13
# Name: Date, Length: 494, dtype: datetime64[ns]

# %% [markdown]
# ### Query 1.4
# In a separate array , calculate the monthwise VWAP (Volume Weighted Average Price ) of the stock.
# ( VWAP = sum(price*volume)/sum(volume) )
# To know more about VWAP , visit - VWAP definition
# {Hint : Create a new dataframe column ‘Month’. The values for this column can be derived from the ‘Date” column by using appropriate pandas functions. Similarly, create a column ‘Year’ and initialize it. Then use the 'groupby()' function by month and year. Finally, calculate the vwap value for each month (i.e. for each group created).

# %%
train['Month'] = train['Date'].dt.month
train['Year'] = train['Date'].dt.year
train['vwap_num'] = train['Close Price']*train['Total Traded Quantity'] # New column to calculate the numerator term of VWAP
query1_4 = train.groupby(['Year','Month']).sum() # GroupBy table
vwap = query1_4['vwap_num']/query1_4['Total Traded Quantity'] # VWAP array
vwap
# Out:
# Year  Month
# 2017  5         950.394555
#       6         940.241388
#       7        1242.465373
#       8        1345.873045
#       9        1386.559390
#       10       1559.883587
#       11       1722.366935
#       12       1718.993098
# 2018  1        2090.182799
#       2        2001.963474
#       3        2191.806388
#       4        2454.844381
#       5        2538.895217
#       6        2171.190569
#       7        1416.504564
#       8        1496.404412
#       9        1342.064999
#       10       1144.336480
#       11       1155.198079
#       12       1265.765748
# 2019  1        1214.545645
#       2        1313.839068
#       3        1378.262288
#       4        1380.115524
#       5        1292.638516
# dtype: float64

# %% [markdown]
# ### Query 1.5
# Write a function to calculate the average price over the last N days of the stock price data where N is a user defined parameter. Write a second function to calculate the profit/loss percentage over the last N days.
# Calculate the average price AND the profit/loss percentages over the course of last -
# 1 week, 2 weeks, 1 month, 3 months, 6 months and 1 year.
# {Note : Profit/Loss percentage between N days is the percentage change between the closing prices of the 2 days }

# %%
def func(N):
    train['Date']=pd.to_datetime(train['Date']) 
    x=(train['Date'].max() - np.timedelta64(N-1,'D'))
    query1_5 = train[(train['Date']>=x)] # Making a dataframe with required range of dates
    avgprice = query1_5['Close Price'].sum()/(N) # Calculating average closing price
    endday = query1_5.tail(1) # Last day of the range
    startday = query1_5.head(1) # First day of the range
    pnl = (endday['Close Price'].sum() - startday['Close Price'].sum())*100/startday['Close Price'].sum() # Calculating P/L
    print ("Average Price: %0.5f" %avgprice)
    print ("Profit/Loss percentage: %0.5f%%" %pnl)


func(7) # 1 week
func(14) # 2 weeks
func(30) # 1 month
func(89) # 3 months
func(181) # 6 months
func(365) # 1 year
# Out:
# Average Price: 902.94286
# Profit/Loss percentage: -3.09222%
# Average Price: 830.08571
# Profit/Loss percentage: -6.46594%
# Average Price: 745.09167
# Profit/Loss percentage: -9.32574%
# Average Price: 864.78146
# Profit/Loss percentage: -5.34014%
# Average Price: 866.98950
# Profit/Loss percentage: 7.63567%
# Average Price: 985.76740
# Profit/Loss percentage: -49.02781%

# %% [markdown]
# ### Query 1.6
# Add a column 'Day_Perc_Change' where the values are the daily change in percentages i.e. the percentage change between 2 consecutive day's closing prices. Instead of using the basic mathematical formula for computing the same, use 'pct_change()' function provided by Pandas for dataframes. You will note that the first entry of the column will have a ‘Nan’ value. Why does this happen? Either remove the first row, or set the entry to 0 before proceeding.

# %%
train['Day_Perc_Change'] = (train['Close Price'].pct_change())*100
train.iloc[0,-1] = 0 # Setting row 1 value to 0
train
# Out:
#        Symbol Series       Date  Prev Close  Open Price  High Price  \
# 0    JUBLFOOD     EQ 2017-05-15      986.35      991.85     1031.00
# 1    JUBLFOOD     EQ 2017-05-16     1025.45     1028.50     1054.85
# 2    JUBLFOOD     EQ 2017-05-17     1050.65     1044.00     1058.75
# 3    JUBLFOOD     EQ 2017-05-18     1049.05     1039.70     1049.15
# 4    JUBLFOOD     EQ 2017-05-19     1019.35     1022.00     1042.20
# 5    JUBLFOOD     EQ 2017-05-22     1018.10     1018.10     1038.00
# 6    JUBLFOOD     EQ 2017-05-23     1030.30     1030.00     1030.00
# 7    JUBLFOOD     EQ 2017-05-24      993.15      995.00     1005.90
# 8    JUBLFOOD     EQ 2017-05-25      976.45      974.45     1024.00
# 9    JUBLFOOD     EQ 2017-05-26     1014.95     1024.00     1035.00
# 10   JUBLFOOD     EQ 2017-05-29      992.70      997.80      998.40
# 11   JUBLFOOD     EQ 2017-05-30      940.35      880.10      921.00
# 12   JUBLFOOD     EQ 2017-05-31      909.15      911.95      925.00
# 13   JUBLFOOD     EQ 2017-06-01      914.90      920.00      920.00
# 14   JUBLFOOD     EQ 2017-06-02      912.25      914.25      934.80
# 15   JUBLFOOD     EQ 2017-06-05      930.85      931.00      949.00
# 16   JUBLFOOD     EQ 2017-06-06      936.05      936.05      965.80
# 17   JUBLFOOD     EQ 2017-06-07      952.55      957.20      961.35
# 18   JUBLFOOD     EQ 2017-06-08      955.20      952.00      971.90
# 19   JUBLFOOD     EQ 2017-06-09      963.80      964.00      975.00
# 20   JUBLFOOD     EQ 2017-06-12      969.10      960.00      966.85
# 21   JUBLFOOD     EQ 2017-06-13      959.55      961.15      973.00
# 22   JUBLFOOD     EQ 2017-06-14      970.05      962.00      968.00
# 23   JUBLFOOD     EQ 2017-06-15      962.60      959.95      964.90
# 24   JUBLFOOD     EQ 2017-06-16      959.25      963.00      968.75
# 25   JUBLFOOD     EQ 2017-06-19      938.20      940.10      944.95
# 26   JUBLFOOD     EQ 2017-06-20      924.65      923.50      930.45
# 27   JUBLFOOD     EQ 2017-06-21      924.00      923.00      938.10
# 28   JUBLFOOD     EQ 2017-06-22      926.20      929.90      929.90
# 29   JUBLFOOD     EQ 2017-06-23      913.25      914.00      934.50
# ..        ...    ...        ...         ...         ...         ...
# 465  JUBLFOOD     EQ 2019-03-27     1466.60     1466.00     1469.45
# 466  JUBLFOOD     EQ 2019-03-28     1446.60     1444.60     1466.65
# 467  JUBLFOOD     EQ 2019-03-29     1459.40     1460.00     1461.45
# 468  JUBLFOOD     EQ 2019-04-01     1444.00     1456.00     1487.70
# 469  JUBLFOOD     EQ 2019-04-02     1460.30     1458.00     1474.70
# 470  JUBLFOOD     EQ 2019-04-03     1441.20     1448.45     1461.00
# 471  JUBLFOOD     EQ 2019-04-04     1423.15     1428.20     1442.90
# 472  JUBLFOOD     EQ 2019-04-05     1432.85     1437.00     1444.25
# 473  JUBLFOOD     EQ 2019-04-08     1417.60     1424.90     1437.50
# 474  JUBLFOOD     EQ 2019-04-09     1427.70     1428.95     1433.00
# 475  JUBLFOOD     EQ 2019-04-10     1429.55     1428.00     1433.95
# 476  JUBLFOOD     EQ 2019-04-11     1409.65     1409.00     1416.30
# 477  JUBLFOOD     EQ 2019-04-12     1375.30     1378.40     1380.95
# 478  JUBLFOOD     EQ 2019-04-15     1361.50     1366.00     1384.85
# 479  JUBLFOOD     EQ 2019-04-16     1370.40     1377.00     1394.75
# 480  JUBLFOOD     EQ 2019-04-18     1381.15     1387.00     1391.55
# 481  JUBLFOOD     EQ 2019-04-22     1345.15     1340.75     1348.00
# 482  JUBLFOOD     EQ 2019-04-23     1331.05     1323.00     1349.00
# 483  JUBLFOOD     EQ 2019-04-24     1316.10     1320.00     1334.00
# 484  JUBLFOOD     EQ 2019-04-25     1317.00     1327.00     1354.90
# 485  JUBLFOOD     EQ 2019-04-26     1327.90     1336.15     1354.90
# 486  JUBLFOOD     EQ 2019-04-30     1342.80     1341.60     1341.60
# 487  JUBLFOOD     EQ 2019-05-02     1328.50     1329.70     1364.40
# 488  JUBLFOOD     EQ 2019-05-03     1345.90     1345.95     1362.95
# 489  JUBLFOOD     EQ 2019-05-06     1326.35     1317.00     1326.70
# 490  JUBLFOOD     EQ 2019-05-07     1299.85     1305.00     1320.00
# 491  JUBLFOOD     EQ 2019-05-08     1282.25     1272.00     1276.55
# 492  JUBLFOOD     EQ 2019-05-09     1262.45     1266.00     1278.00
# 493  JUBLFOOD     EQ 2019-05-10     1268.80     1278.80     1294.80
# 494  JUBLFOOD     EQ 2019-05-13     1264.50     1269.95     1269.95
#
#      Low Price  Last Price  Close Price  Average Price  Total Traded Quantity  \
# 0       983.55     1029.60      1025.45        1009.72                 576466
# 1      1028.50     1052.00      1050.65        1042.26                 487510
# 2      1024.20     1047.00      1049.05        1039.93                 393751
# 3      1012.20     1014.10      1019.35        1033.80                 381432
# 4      1011.00     1012.55      1018.10        1025.24                 287852
# 5      1015.00     1022.85      1030.30        1026.60                 321837
# 6       990.00      990.00       993.15        1009.44                 342845
# 7       966.00      974.45       976.45         988.12                 448045
# 8       965.25     1024.00      1014.95         998.09                 524803
# 9       982.50      993.95       992.70        1013.20                 391221
# 10      925.00      937.20       940.35         957.94                 974901
# 11      817.20      910.20       909.15         876.28                5504664
# 12      888.00      917.00       914.90         909.16                1195336
# 13      898.10      912.50       912.25         909.03                 921483
# 14      908.30      932.00       930.85         924.04                 620511
# 15      926.10      932.10       936.05         940.24                 514033
# 16      935.20      956.90       952.55         954.52                1196195
# 17      945.00      956.45       955.20         952.61                 472750
# 18      952.00      963.40       963.80         963.02                 500353
# 19      952.45      973.00       969.10         962.46                 370792
# 20      950.10      957.50       959.55         959.32                 265930
# 21      953.00      970.70       970.05         965.68                 421456
# 23       6  2017  2.222640e+08        -0.348016
# 24       6  2017  4.657075e+08        -2.194423
# 25       6  2017  6.074331e+08        -1.444255
# 26       6  2017  2.697341e+08        -0.070297
# 27       6  2017  4.265883e+08         0.238095
# 28       6  2017  3.317901e+08        -1.398186
# 29       6  2017  5.321259e+08         1.062141
# ..     ...   ...           ...              ...
# 465      3  2019  1.598470e+09        -1.363698
# 466      3  2019  2.115199e+09         0.884833
# 467      3  2019  1.736074e+09        -1.055228
# 468      4  2019  2.049343e+09         1.128809
# 469      4  2019  1.530161e+09        -1.307950
# 470      4  2019  1.291758e+09        -1.252429
# 471      4  2019  1.417665e+09         0.681587
# 472      4  2019  1.339385e+09        -1.064312
# 473      4  2019  1.171482e+09         0.712472
# 474      4  2019  1.234920e+09         0.129579
# 475      4  2019  9.516195e+08        -1.392046
# 476      4  2019  1.958937e+09        -2.436775
# 477      4  2019  2.101935e+09        -1.003417
# 478      4  2019  1.524275e+09         0.653691
# 479      4  2019  1.755067e+09         0.784442
# 480      4  2019  1.778653e+09        -2.606524
# 481      4  2019  9.934172e+08        -1.048210
# 482      4  2019  1.262324e+09        -1.123173
# 483      4  2019  1.274166e+09         0.068384
# 484      4  2019  1.532361e+09         0.827639
# 485      4  2019  1.755350e+09         1.122072
# 486      4  2019  1.191223e+09        -1.064939
# 487      5  2019  2.015584e+09         1.309748
# 488      5  2019  1.373459e+09        -1.452560
# 489      5  2019  1.473581e+09        -1.997964
# 490      5  2019  1.679003e+09        -1.354002
# 491      5  2019  1.312338e+09        -1.544161
# 492      5  2019  8.196651e+08         0.502990
# 493      5  2019  1.128450e+09        -0.338903
# 494      5  2019  9.275487e+08        -1.731910
#
# [494 rows x 19 columns]

# %% [markdown]
# ### Query 1.7
# Add another column 'Trend' whose values are:
# 'Slight or No change' for 'Day_Perc_Change' in between -0.5 and 0.5
# 'Slight positive' for 'Day_Perc_Change' in between 0.5 and 1
# 'Slight negative' for 'Day_Perc_Change' in between -0.5 and -1
# 'Positive' for 'Day_Perc_Change' in between 1 and 3
# 'Negative' for 'Day_Perc_Change' in between -1 and -3
# 'Among top gainers' for 'Day_Perc_Change' in between 3 and 7
# 'Among top losers' for 'Day_Perc_Change' in between -3 and -7
# 'Bull run' for 'Day_Perc_Change' >7
# 'Bear drop' for 'Day_Perc_Change' <-7

# %%
def perchange(i):
    a=''
    if (i>-0.5) & (i<0.5):
        a = 'Slight or No change'
    elif (i>0.5) & (i<1):
        a = 'Slight positive'
    elif (i<-0.5) & (i>-1):
        a = 'Slight negative'
    elif (i>1) & (i<3):
        a = 'Positive'
    elif (i>-3) & (i<-1):
        a = 'Negative' 
    elif (i>3) & (i<7):
        a = 'Among top gainers'
    elif (i>-7) & (i<-3):
        a = 'Among top losers'
    elif i>7:
        a = 'Bull run'
    else:
        a = 'Bear drop'
    return a   
    
train['Trend'] = train['Day_Perc_Change'].map(perchange)
train.head()
# Out:
#      Symbol Series       Date  Prev Close  Open Price  High Price  Low Price  \
# 0  JUBLFOOD     EQ 2017-05-15      986.35      991.85     1031.00     983.55
# 1  JUBLFOOD     EQ 2017-05-16     1025.45     1028.50     1054.85    1028.50
# 2  JUBLFOOD     EQ 2017-05-17     1050.65     1044.00     1058.75    1024.20
# 3  JUBLFOOD     EQ 2017-05-18     1049.05     1039.70     1049.15    1012.20
# 4  JUBLFOOD     EQ 2017-05-19     1019.35     1022.00     1042.20    1011.00
#
#    Last Price  Close Price  Average Price  Total Traded Quantity  \
# 0     1029.60      1025.45        1009.72                 576466
# 1     1052.00      1050.65        1042.26                 487510
# 2     1047.00      1049.05        1039.93                 393751
# 3     1014.10      1019.35        1033.80                 381432
# 4     1012.55      1018.10        1025.24                 287852
#
#        Turnover  No. of Trades  Deliverable Qty  % Dly Qt to Traded Qty  \
# 0  5.820685e+08          19888           115368                   20.01
# 1  5.081107e+08          15487            84859                   17.41
# 2  4.094726e+08          15205            61936                   15.73
# 3  3.943245e+08          10345            40599                   10.64
# 4  2.951171e+08           9834            60049                   20.86
#
#    Month  Year      vwap_num  Day_Perc_Change                Trend
# 0      5  2017  5.911371e+08         0.000000  Slight or No change
# 1      5  2017  5.122024e+08         2.457458             Positive
# 2      5  2017  4.130645e+08        -0.152287  Slight or No change
# 3      5  2017  3.888127e+08        -2.831133             Negative
# 4      5  2017  2.930621e+08        -0.122627  Slight or No change

# %% [markdown]
# ### Query 1.7

# %%
avg = train.groupby(['Trend']).mean()
avg[['Total Traded Quantity']] # Average Total Traded Quantity
median = train.groupby(['Trend']).median()
median[['Total Traded Quantity']] # Median Total Traded Quantity
# Out:
#                      Total Traded Quantity
# Trend
# Among top gainers             2.036205e+06
# Among top losers              2.036602e+06
# Bear drop                     3.104380e+06
# Bull run                      6.130196e+06
# Negative                      1.277590e+06
# Positive                      1.364358e+06
# Slight negative               1.031924e+06
# Slight or No change           1.116733e+06
# Slight positive               9.683426e+05

# %%
train.to_csv("week2.csv",index=False)

# %%
train.head()
# Out:
#      Symbol Series       Date  Prev Close  Open Price  High Price  Low Price  \
# 0  JUBLFOOD     EQ 2017-05-15      986.35      991.85     1031.00     983.55
# 1  JUBLFOOD     EQ 2017-05-16     1025.45     1028.50     1054.85    1028.50
# 2  JUBLFOOD     EQ 2017-05-17     1050.65     1044.00     1058.75    1024.20
# 3  JUBLFOOD     EQ 2017-05-18     1049.05     1039.70     1049.15    1012.20
# 4  JUBLFOOD     EQ 2017-05-19     1019.35     1022.00     1042.20    1011.00
#
#    Last Price  Close Price  Average Price  Total Traded Quantity  \
# 0     1029.60      1025.45        1009.72                 576466
# 1     1052.00      1050.65        1042.26                 487510
# 2     1047.00      1049.05        1039.93                 393751
# 3     1014.10      1019.35        1033.80                 381432
# 4     1012.55      1018.10        1025.24                 287852
#
#        Turnover  No. of Trades  Deliverable Qty  % Dly Qt to Traded Qty  \
# 0  5.820685e+08          19888           115368                   20.01
# 1  5.081107e+08          15487            84859                   17.41
# 2  4.094726e+08          15205            61936                   15.73
# 3  3.943245e+08          10345            40599                   10.64
# 4  2.951171e+08           9834            60049                   20.86
#
#    Month  Year      vwap_num  Day_Perc_Change                Trend
# 0      5  2017  5.911371e+08         0.000000  Slight or No change
# 1      5  2017  5.122024e+08         2.457458             Positive
# 2      5  2017  4.130645e+08        -0.152287  Slight or No change
# 3      5  2017  3.888127e+08        -2.831133             Negative
# 4      5  2017  2.930621e+08        -0.122627  Slight or No change
